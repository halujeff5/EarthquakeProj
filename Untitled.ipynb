# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math
pd.set_option('display.max_rows', 300)
import pickle
from datetime import datetime
import dateutil.parser

# %%
#loading csv
df1=pd.read_csv('query (5).csv')

# %%
#coordinates of our data in question
df1['latitude'].max(), df1['latitude'].min(), df1.longitude.max(), df1.longitude.min()
# Out:
# (38.467, 37.231, -121.3955, -123.008)

# %%
#dataframe
df1.time
# Out:
# 0        2020-08-03T06:44:17.110Z
# 1        2020-08-02T12:40:24.270Z
# 2        2020-07-31T19:45:52.900Z
# 3        2020-07-30T02:57:49.470Z
# 4        2020-07-30T02:51:28.800Z
#                    ...
# 14113    2010-01-01T20:13:06.920Z
# 14114    2010-01-01T14:59:15.230Z
# 14115    2010-01-01T10:06:09.310Z
# 14116    2010-01-01T05:25:27.130Z
# 14117    2010-01-01T02:27:46.670Z
# Name: time, Length: 14118, dtype: object

# %%
# datetimeOBJ=[pd.to_datetime(x,infer_datetime_format=True) for x in df1.time3]
datetimeOBJ=df1.time

# %%
d = [dateutil.parser.parse(x) for x in datetimeOBJ]

# %%
d
# Out:
# [datetime.datetime(2020, 8, 3, 6, 44, 17, 110000, tzinfo=tzutc()),
#  datetime.datetime(2020, 8, 2, 12, 40, 24, 270000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 31, 19, 45, 52, 900000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 30, 2, 57, 49, 470000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 30, 2, 51, 28, 800000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 30, 2, 40, 31, 60000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 30, 0, 40, 41, 370000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 29, 9, 40, 34, 440000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 29, 3, 8, 48, 490000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 28, 23, 41, 12, 520000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 28, 22, 24, 57, 60000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 28, 21, 44, 28, 640000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 28, 19, 21, 27, 110000, tzinfo=tzutc()),
#  datetime.datetime(2020, 7, 28, 18, 30, 29, 680000, tzinfo=tzutc()),
# ...

# %%
frame1=pd.DataFrame(d)

# %%
frames = [df1, frame1]
df2=pd.concat(frames, axis =1)

# %%
df2.rename(columns={0:'dt'}, inplace=True)

# %%
from tensorflow import keras

# %%
#importing libraries
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler, StandardScaler

# %%
with open ('vis', 'wb') as f:
    pickle.dump(df2, f)
